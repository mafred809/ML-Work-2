# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv('/Users/mafredtucker/Documents/GitHub/ML-AI/ML-Work-2/Performance.csv')

# %%
df.head(10)
# Out:
#    student_id gender  age  grade_level  english_score  math_score  \
# 0           1      M   16           11             80          90
# 1           2      F   15           10             70          80
# 2           3      F   17           12             88          72
# 3           4      M   16           11             65          82
# 4           5      F   14            9             75          88
# 5           6      F   17           12             95          85
# 6           7      M   15           10             82          95
# 7           8      F   16           11             68          75
# 8           9      F   14            9             85          82
# 9          10      M   17           12             78          80
#
#    science_score  social_studies_score
# 0             85                    75
# 1             92                    78
# 2             90                    80
# 3             78                    85
# 4             85                    80
# 5             92                    90
# 6             88                    78
# 7             80                    72
# 8             90                    88
# 9             82                    88

# %%
df.tail()
# Out:
#     student_id gender  age  grade_level  english_score  math_score  \
# 35          36      F   16           11             83          86
# 36          37      F   17           12             91          93
# 37          38      M   16           11             86          87
# 38          39      F   15           10             89          90
# 39          40      M   15            9             80          82
#
#     science_score  social_studies_score
# 35             87                    84
# 36             92                    90
# 37             85                    82
# 38             92                    88
# 39             81                    75

# %%
mf = df['gender'].value_counts()
mf
# Out:
# F    21
# M    19
# Name: gender, dtype: int64

# %%
average_age =df['age'].mean()
print(average_age)
# Out:
# 15.675

# %%
df.isnull().sum()
# Out:
# student_id              0
# gender                  0
# age                     0
# grade_level             0
# english_score           0
# math_score              0
# science_score           0
# social_studies_score    0
# dtype: int64

# %%
English_scores = df['english_score'].max() -df['english_score'].min()
English_scores
# Out:
# 30

# %%
corr_coeff = df['english_score'].corr(df['science_score'])
corr_coeff
# Out:
# 0.6293841680797964

# %%
plt.scatter(df['math_score'], df['social_studies_score'])
plt.xlabel('Math Score')
plt.ylabel('Social Studies Score')
plt.show()

# %%
df['total_score'] = df['english_score'] + df['math_score'] + df['science_score'] + df['social_studies_score']
highest_score = df['total_score'].max()
highest_score_student = df.loc[df['total_score'] == highest_score]
print(highest_score_student[['student_id', 'english_score', 'math_score', 'science_score', 'social_studies_score']])
# Out:
#     student_id  english_score  math_score  science_score  social_studies_score
# 31          32             95          97             96                    94

# %%
Quan1 = df.quantile(0.25)
Quan3 = df.quantile(0.75)
IQR = Quan3 - Quan1

outliers = ((df < (Quan1 - 1.5 * IQR)) | (df > (Quan3 + 1.5 * IQR))).any(axis=1)

print("Outliers ")
print(df[outliers])
# Out:
# Outliers
#     student_id gender  age  grade_level  english_score  math_score  \
# 14          15      F   15           10             92          90
#
#     science_score  social_studies_score  total_score
# 14             70                    82          334
# C:\Users\Papayaw\AppData\Local\Temp\ipykernel_8320\773967848.py:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers = ((df < (Quan1 - 1.5 * IQR)) | (df > (Quan3 + 1.5 * IQR))).any(axis=1)

# %%
std_dev = np.std(df['english_score'])

print("Standard Deviation of English Scores is ", std_dev)
# Out:
# Standard Deviation of English Scores is  8.04794228359026

# %%
plt.hist(df['math_score'], bins=5)

plt.xlabel('Math Score')
plt.ylabel('Frequency')

plt.show()

# %%
median_sci_score = np.median(df['science_score'])

print("The Median Science Score is ", median_sci_score)
# Out:
# The Median Science Score is  88.0

# %%
english_scores = df['english_score']
Quan1 = english_scores.quantile(0.25)
Quan3 = english_scores.quantile(0.75)
IQR = Quan3 - Quan1

print("IQR of English Scores is ", IQR)
# Out:
# IQR of English Scores is  11.0

# %%
english_total = df['english_score'].sum()
math_total = df['math_score'].sum()
science_total = df['science_score'].sum()
social_studies_total = df['social_studies_score'].sum()

max_total = max(english_total, math_total, science_total, social_studies_total)
if max_total == english_total:
    subject = 'English'
elif max_total == science_total:
    subject = 'Science'
elif max_total == math_total:
    subject = 'Math'
else:
    subject = 'social studies'
    
print(" The subject with the highest overall score is ", subject)
# Out:
#  The subject with the highest overall score is  Science

# %%
grouped = df.groupby('gender')['math_score']

fig, ax = plt.subplots()
ax.boxplot([grouped.get_group('M'), grouped.get_group('F')])

ax.set_xticklabels(['Male', 'Female'])
ax.set_xlabel('Gender')
ax.set_ylabel('Math Score')
ax.set_title('Math Scores Based on Gender')

plt.show()

# %%
mode_grade = df['grade_level'].mode()[0]

print("The mode of grades is ", mode_grade)
# Out:
# The mode of grades is  11

# %%
print(df.isnull().sum())
# Out:
# student_id              0
# gender                  0
# age                     0
# grade_level             0
# english_score           0
# math_score              0
# science_score           0
# social_studies_score    0
# total_score             0
# dtype: int64

# %%
corr_matrix = df.corr()

print("Correlation Matrix: ")
print(corr_matrix)

corr_threshold = 0.7
corr_pairs = {}

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        col1 = corr_matrix.columns[i]
        col2 = corr_matrix.columns[j]
        
        if abs(corr_matrix.iloc[i, j]) > corr_threshold:
            corr_pairs[(col1, col2)] = corr_matrix.iloc[i, j]
            
if len(corr_pairs) > 0:
    print("\nHighly correlated variables: ")
    for pair, corr in corr_pairs.items():
        print(pair[0], "-", pair[1], ":", corr)
else:
    print("\nLow correlated variables: ")
# Out:
# Correlation Matrix:
#                       student_id       age  grade_level  english_score  \
# student_id              1.000000  0.032300    -0.045710       0.387646
# age                     0.032300  1.000000     0.965963       0.284062
# grade_level            -0.045710  0.965963     1.000000       0.305335
# english_score           0.387646  0.284062     0.305335       1.000000
# math_score              0.250597  0.113057     0.129292       0.701187
# science_score           0.159167  0.314896     0.310005       0.629384
# social_studies_score    0.191478  0.348830     0.406362       0.746895
# total_score             0.293684  0.301629     0.327436       0.897919
#
#                       math_score  science_score  social_studies_score  \
# student_id              0.250597       0.159167              0.191478
# age                     0.113057       0.314896              0.348830
# grade_level             0.129292       0.310005              0.406362
# english_score           0.701187       0.629384              0.746895
# math_score              1.000000       0.615301              0.673596
# science_score           0.615301       1.000000              0.671446
# social_studies_score    0.673596       0.671446              1.000000
# total_score             0.863773       0.826952              0.884650
#
#                       total_score
# student_id               0.293684
# age                      0.301629
# grade_level              0.327436
# english_score            0.897919
# math_score               0.863773
# science_score            0.826952
# social_studies_score     0.884650
# total_score              1.000000
#
# Highly correlated variables:
# grade_level - age : 0.9659625755616812
# math_score - english_score : 0.7011868109927599
# social_studies_score - english_score : 0.746894513283115
# total_score - english_score : 0.8979190311377772
# total_score - math_score : 0.863773190603858
# total_score - science_score : 0.826952082164644
# total_score - social_studies_score : 0.8846503686363747

# %%
sns.pairplot(df, diag_kind='hist')

# %%
age_range = df['age'].max() - df['age'].min()
print("The range of ages in the dataset is ", age_range)
# Out:
# The range of ages in the dataset is  3

# %%
scores = df[['english_score', 'math_score', 'science_score', 'social_studies_score']]

totals = scores.sum(axis=1)

lowest_scoring_student_id = totals.idxmin()

print(df.loc[lowest_scoring_student_id])
# Out:
# student_id               13
# gender                    M
# age                      14
# grade_level               9
# english_score            65
# math_score               68
# science_score            75
# social_studies_score     70
# total_score             278
# Name: 12, dtype: object

# %%
mean_math_score = df['math_score'].mean()
median_math_score = df['math_score'].median()

difference = mean_math_score - median_math_score

print('Mean_math_score: ', mean_math_score)
print('Median_math_score', median_math_score)
print('Difference:', difference)
# Out:
# Mean_math_score:  85.175
# Median_math_score 85.5
# Difference: -0.32500000000000284

# %%
ss_score = df.loc[df['student_id'] == 15, 'social_studies_score'].iloc[0]

ss_mean = df['social_studies_score'].mean()
ss_std = df['social_studies_score'].std()

ss_zscore = (ss_score - ss_mean) / ss_std

print(f"The z-score for the social studies score of student ID 15 is {ss_zscore:.2f}")
# Out:
# The z-score for the social studies score of student ID 15 is -0.15
